# %% [markdown]
# ## Hotkeys for Vim-Bindings
#
# [source](https://github.com/lambdalisue/jupyter-vim-binding/blob/master/vim_binding.js#L264-L335)

# %%
hotkeys = {
    
      'ctrl-shift--': 'jupyter-notebook:split-cell-at-cursor',
      'ctrl-shift-subtract': 'jupyter-notebook:split-cell-at-cursor',
      'ctrl-shift-j': 'vim-binding:select-next-cell-and-edit',
      'ctrl-shift-k': 'vim-binding:select-previous-cell-and-edit',
      'alt-enter': 'jupyter-notebook:run-cell-and-insert-below',
      'ctrl-enter': 'jupyter-notebook:run-cell',
      'shift-enter': 'jupyter-notebook:run-cell-and-select-next',
      'ctrl-shift-enter': 'jupyter-notebook:run-all-cells',
      'ctrl-s': 'jupyter-notebook:save-notebook',
      'ctrl-1': 'vim-binding:change-cell-to-code-and-edit',
      'ctrl-2': 'vim-binding:change-cell-to-markdown-and-edit',
      'ctrl-3': 'vim-binding:change-cell-to-raw-and-edit',
      'ctrl-c': 'jupyter-notebook:interrupt-kernel',
      'shift-o': 'jupyter-notebook:insert-cell-above',
      'o': 'jupyter-notebook:insert-cell-below',
      'y,y': 'jupyter-notebook:copy-cell',
      'd,d': 'jupyter-notebook:cut-cell',
      'shift-p': 'jupyter-notebook:paste-cell-above',
      'p': 'jupyter-notebook:paste-cell-below',
      'esc': 'jupyter-notebook:close-pager',
      'q': 'jupyter-notebook:close-pager',
      'enter': 'jupyter-notebook:enter-edit-mode',
      'i': 'jupyter-notebook:enter-edit-mode',
      'j': 'vim-binding:scroll-down',
      'k': 'vim-binding:scroll-up',
      'z,z': 'jupyter-notebook:scroll-cell-center',
      'z,t': 'jupyter-notebook:scroll-cell-top',
      'ctrl-j': 'jupyter-notebook:select-next-cell',
      'ctrl-k': 'jupyter-notebook:select-previous-cell',
      'shift-j': 'jupyter-notebook:extend-marked-cells-below',
      'shift-k': 'jupyter-notebook:extend-marked-cells-above',
      'shift-m': 'jupyter-notebook:merge-cells',
      'ctrl-m': 'jupyter-notebook:merge-cell-with-next-cell',
      'ctrl-shift-m': 'jupyter-notebook:merge-cell-with-previous-cell',
      'g,g': 'vim-binding:select-first-cell',
      'shift-g': 'vim-binding:select-last-cell',
      'ctrl-u': 'jupyter-notebook:scroll-notebook-up',
      'ctrl-d': 'jupyter-notebook:scroll-notebook-down',
      'u': 'jupyter-notebook:undo-cell-deletion',
      'ctrl-1': 'jupyter-notebook:change-cell-to-code',
      'ctrl-2': 'jupyter-notebook:change-cell-to-markdown',
      'ctrl-3': 'jupyter-notebook:change-cell-to-raw',
      'shift-h': 'jupyter-notebook:show-keyboard-shortcuts',
      'shift-l': 'jupyter-notebook:toggle-cell-line-numbers',
      'shift-v': 'jupyter-notebook:toggle-cell-output-collapsed',
      'shift-s': 'jupyter-notebook:toggle-cell-output-scrolled',
      'ctrl-s': 'jupyter-notebook:save-notebook',
      'shift-r': 'jupyter-notebook:rename-notebook',
      'alt-enter': 'jupyter-notebook:run-cell-and-insert-below',
      'ctrl-enter': 'jupyter-notebook:run-cell',
      'shift-enter': 'jupyter-notebook:run-cell-and-select-next',
      'ctrl-shift-enter': 'jupyter-notebook:run-all-cells',
      'z,a': 'jupyter-notebook:toggle-cell-output-collapsed',
      'z,shift-a': 'jupyter-notebook:toggle-all-cells-output-collapsed',
      'z,m': 'vim-binding:collapse-output',
      'z,shift-m': 'vim-binding:collapse-all-output',
      'z,r': 'vim-binding:expand-output',
      'z,shift-r': 'vim-binding:expand-all-output',
      '0,0': 'jupyter-notebook:confirm-restart-kernel',
      '1': 'jupyter-notebook:change-cell-to-heading-1',
      '2': 'jupyter-notebook:change-cell-to-heading-2',
      '3': 'jupyter-notebook:change-cell-to-heading-3',
      '4': 'jupyter-notebook:change-cell-to-heading-4',
      '5': 'jupyter-notebook:change-cell-to-heading-5',
      '6': 'jupyter-notebook:change-cell-to-heading-6'
    }
       
for k, v in hotkeys.items():
    print("Hotkey {}: {}".format(k, v))
# Out:
# Hotkey z,m: vim-binding:collapse-output
# Hotkey ctrl-k: jupyter-notebook:select-previous-cell
# Hotkey o: jupyter-notebook:insert-cell-below
# Hotkey ctrl-3: jupyter-notebook:change-cell-to-raw
# Hotkey shift-j: jupyter-notebook:extend-marked-cells-below
# Hotkey z,shift-a: jupyter-notebook:toggle-all-cells-output-collapsed
# Hotkey ctrl-shift-m: jupyter-notebook:merge-cell-with-previous-cell
# Hotkey shift: jupyter-notebook:ignore
# Hotkey z,t: jupyter-notebook:scroll-cell-top
# Hotkey ctrl-enter: jupyter-notebook:run-cell
# Hotkey z,a: jupyter-notebook:toggle-cell-output-collapsed
# Hotkey ctrl-m: jupyter-notebook:merge-cell-with-next-cell
# Hotkey shift-l: jupyter-notebook:toggle-cell-line-numbers
# Hotkey k: vim-binding:scroll-up
# Hotkey ctrl-1: jupyter-notebook:change-cell-to-code
# Hotkey shift-o: jupyter-notebook:insert-cell-above
# Hotkey shift-g: vim-binding:select-last-cell
# Hotkey ctrl-u: jupyter-notebook:scroll-notebook-up
# Hotkey 1: jupyter-notebook:change-cell-to-heading-1
# Hotkey shift-h: jupyter-notebook:show-keyboard-shortcuts
# Hotkey z,shift-m: vim-binding:collapse-all-output
# Hotkey shift-k: jupyter-notebook:extend-marked-cells-above
# Hotkey shift-v: jupyter-notebook:toggle-cell-output-collapsed
# Hotkey q: jupyter-notebook:close-pager
# Hotkey j: vim-binding:scroll-down
# Hotkey 3: jupyter-notebook:change-cell-to-heading-3
# Hotkey d,d: jupyter-notebook:cut-cell
# Hotkey shift-m: jupyter-notebook:merge-cells
# Hotkey p: jupyter-notebook:paste-cell-below
# Hotkey ctrl-2: jupyter-notebook:change-cell-to-markdown
# Hotkey ctrl-j: jupyter-notebook:select-next-cell
# Hotkey z,shift-r: vim-binding:expand-all-output
# Hotkey 0,0: jupyter-notebook:confirm-restart-kernel
# Hotkey ctrl-shift-subtract: jupyter-notebook:split-cell-at-cursor
# Hotkey 2: jupyter-notebook:change-cell-to-heading-2
# Hotkey ctrl-shift-j: vim-binding:select-next-cell-and-edit
# Hotkey 4: jupyter-notebook:change-cell-to-heading-4
# Hotkey enter: jupyter-notebook:enter-edit-mode
# Hotkey shift-p: jupyter-notebook:paste-cell-above
# Hotkey 5: jupyter-notebook:change-cell-to-heading-5
# Hotkey i: jupyter-notebook:enter-edit-mode
# Hotkey shift-s: jupyter-notebook:toggle-cell-output-scrolled
# Hotkey ctrl-c: jupyter-notebook:interrupt-kernel
# Hotkey esc: jupyter-notebook:close-pager
# Hotkey u: jupyter-notebook:undo-cell-deletion
# Hotkey ctrl-d: jupyter-notebook:scroll-notebook-down
# Hotkey shift-r: jupyter-notebook:rename-notebook
# Hotkey ctrl-shift-k: vim-binding:select-previous-cell-and-edit
# Hotkey z,r: vim-binding:expand-output
# Hotkey 6: jupyter-notebook:change-cell-to-heading-6
# Hotkey g,g: vim-binding:select-first-cell
# Hotkey shift-enter: jupyter-notebook:run-cell-and-select-next
# Hotkey z,z: jupyter-notebook:scroll-cell-center
# Hotkey ctrl-shift--: jupyter-notebook:split-cell-at-cursor
# Hotkey y,y: jupyter-notebook:copy-cell
# Hotkey alt-enter: jupyter-notebook:run-cell-and-insert-below
# Hotkey ctrl-shift-enter: jupyter-notebook:run-all-cells
# Hotkey ctrl-s: jupyter-notebook:save-notebook
